# %%
# Python

# %% [markdown]
# # map
# # reduce
# # lamda
# # list and tuple d/f
# # dictionaries
# # five pillars of oops
# # loops
# # wap that can be done with the help of for as well as while loop.

# %%
# numpy

# %% [markdown]
# # how to create 1d, 2d, 3d
# # linear algo.- dot , determinents, inverse, transpose, Rank, broadcasting.

# %%
# pandas

# %% [markdown]
# # d/f b/w dataframe and series.
# # in how many ways we can create data frames.
# # how to detect the outliers
# # modify column, filter, loc, iloc
# # correlation

# %%
# visualization

# %% [markdown]
# # graph
# # matplotlib vs seaborn

# %%
# machine learning

# %% [markdown]
# # what is ml
# # application
# # d/f b/w supervised & unsupervised
# # regression vs classification
# # mse, rmse, r2 score, AME
# # classification report
# # confusion matrix
# # bagging and boosting
# # feature engineering
# # encoding methods

# %%
# deep learning

# %% [markdown]
# # d/f b/w ml and deep learning
# # d/f b/w ann, cnn, rnn
# # activation function
# # how to increase the accuracy of the model - dropout layers, early stopping, inc. epochs, activation change, add layers.
