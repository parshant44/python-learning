# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
corpus=""""Dream, dream, dream. Dreams transform into thoughts and thoughts result in action." This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress. He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. His wisdom continues to motivate generations to innovate and contribute meaningfully to society.
"""

# %%
print(corpus)
# Out:
# "Dream, dream, dream. Dreams transform into thoughts and thoughts result in action." This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress. He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. His wisdom continues to motivate generations to innovate and contribute meaningfully to society.

# %%
##  Tokenization
## Sentence-->paragraphs
# creating sentences from the corpus(paragraph)
from nltk.tokenize import sent_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
documents=sent_tokenize(corpus)
documents
# Out:
# ['"Dream, dream, dream.',
#  'Dreams transform into thoughts and thoughts result in action."',
#  'This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress.',
#  'He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes.',
#  'Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success.',
#  'His wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# "Dream, dream, dream.
# Dreams transform into thoughts and thoughts result in action."
# This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress.
# He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes.
# Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success.
# His wisdom continues to motivate generations to innovate and contribute meaningfully to society.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['``',
#  'Dream',
#  ',',
#  'dream',
#  ',',
#  'dream',
#  '.',
#  'Dreams',
#  'transform',
#  'into',
#  'thoughts',
#  'and',
#  'thoughts',
#  'result',
#  'in',
#  'action',
#  '.',
#  "''",
#  'This',
#  'famous',
#  'quote',
#  'by',
#  'Dr.',
#  'APJ',
#  'Abdul',
#  'Kalam',
#  ',',
#  'India',
#  '’',
#  's',
#  'beloved',
#  'former',
#  'President',
#  'and',
#  'scientist',
#  ',',
#  'encapsulates',
#  'his',
#  'belief',
#  'in',
#  'the',
#  'power',
#  'of',
#  'dreams',
#  'to',
#  'drive',
#  'progress',
#  '.',
#  'He',
#  'emphasized',
#  'that',
#  'envisioning',
#  'a',
#  'goal',
#  'sparks',
#  'the',
#  'thought',
#  'process',
#  ',',
#  'which',
#  ',',
#  'when',
#  'coupled',
#  'with',
#  'determination',
#  ',',
#  'leads',
#  'to',
#  'tangible',
#  'outcomes',
#  '.',
#  'Dr.',
#  'Kalam',
#  '’',
#  's',
#  'words',
#  'inspire',
#  'students',
#  'and',
#  'individuals',
#  'to',
#  'pursue',
#  'their',
#  'aspirations',
#  'relentlessly',
# ...

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['``', 'Dream', ',', 'dream', ',', 'dream', '.']
# ['Dreams', 'transform', 'into', 'thoughts', 'and', 'thoughts', 'result', 'in', 'action', '.', "''"]
# ['This', 'famous', 'quote', 'by', 'Dr.', 'APJ', 'Abdul', 'Kalam', ',', 'India', '’', 's', 'beloved', 'former', 'President', 'and', 'scientist', ',', 'encapsulates', 'his', 'belief', 'in', 'the', 'power', 'of', 'dreams', 'to', 'drive', 'progress', '.']
# ['He', 'emphasized', 'that', 'envisioning', 'a', 'goal', 'sparks', 'the', 'thought', 'process', ',', 'which', ',', 'when', 'coupled', 'with', 'determination', ',', 'leads', 'to', 'tangible', 'outcomes', '.']
# ['Dr.', 'Kalam', '’', 's', 'words', 'inspire', 'students', 'and', 'individuals', 'to', 'pursue', 'their', 'aspirations', 'relentlessly', ',', 'highlighting', 'the', 'importance', 'of', 'vision', 'and', 'action', 'in', 'achieving', 'success', '.']
# ...

# %%
#another type of tokenization
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['"',
#  'Dream',
#  ',',
#  'dream',
#  ',',
#  'dream',
#  '.',
#  'Dreams',
#  'transform',
#  'into',
#  'thoughts',
#  'and',
#  'thoughts',
#  'result',
#  'in',
#  'action',
#  '."',
#  'This',
#  'famous',
#  'quote',
#  'by',
#  'Dr',
#  '.',
#  'APJ',
#  'Abdul',
#  'Kalam',
#  ',',
#  'India',
#  '’',
#  's',
#  'beloved',
#  'former',
#  'President',
#  'and',
#  'scientist',
#  ',',
#  'encapsulates',
#  'his',
#  'belief',
#  'in',
#  'the',
#  'power',
#  'of',
#  'dreams',
#  'to',
#  'drive',
#  'progress',
#  '.',
#  'He',
#  'emphasized',
#  'that',
#  'envisioning',
#  'a',
#  'goal',
#  'sparks',
#  'the',
#  'thought',
#  'process',
#  ',',
#  'which',
#  ',',
#  'when',
#  'coupled',
#  'with',
#  'determination',
#  ',',
#  'leads',
#  'to',
#  'tangible',
#  'outcomes',
#  '.',
#  'Dr',
#  '.',
#  'Kalam',
#  '’',
#  's',
#  'words',
#  'inspire',
#  'students',
#  'and',
#  'individuals',
#  'to',
#  'pursue',
#  'their',
#  'aspirations',
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
#import sklearn.line

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['``',
#  'Dream',
#  ',',
#  'dream',
#  ',',
#  'dream.',
#  'Dreams',
#  'transform',
#  'into',
#  'thoughts',
#  'and',
#  'thoughts',
#  'result',
#  'in',
#  'action.',
#  "''",
#  'This',
#  'famous',
#  'quote',
#  'by',
#  'Dr.',
#  'APJ',
#  'Abdul',
#  'Kalam',
#  ',',
#  'India’s',
#  'beloved',
#  'former',
#  'President',
#  'and',
#  'scientist',
#  ',',
#  'encapsulates',
#  'his',
#  'belief',
#  'in',
#  'the',
#  'power',
#  'of',
#  'dreams',
#  'to',
#  'drive',
#  'progress.',
#  'He',
#  'emphasized',
#  'that',
#  'envisioning',
#  'a',
#  'goal',
#  'sparks',
#  'the',
#  'thought',
#  'process',
#  ',',
#  'which',
#  ',',
#  'when',
#  'coupled',
#  'with',
#  'determination',
#  ',',
#  'leads',
#  'to',
#  'tangible',
#  'outcomes.',
#  'Dr.',
#  'Kalam’s',
#  'words',
#  'inspire',
#  'students',
#  'and',
#  'individuals',
#  'to',
#  'pursue',
#  'their',
#  'aspirations',
#  'relentlessly',
#  ',',
#  'highlighting',
#  'the',
#  'importance',
# ...

# %% [markdown]
# # Stemming
# # Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming # is important in natural language understanding (NLU) and natural language processing (NLP).

# %% [markdown]
# # from nltk.stem import PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming=PorterStemmer()
#stemming.stem(words)

# %%
for word in corpus:
    print(word+"---->"+stemming.stem(corpus))
# Out:
# "---->"dream, dream, dream. dreams transform into thoughts and thoughts result in action." this famous quote by dr. apj abdul kalam, india’s beloved former president and scientist, encapsulates his belief in the power of dreams to drive progress. he emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. dr. kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. his wisdom continues to motivate generations to innovate and contribute meaningfully to society.
#
# ...

# %%
stemming.stem(corpus)
# Out:
# '"dream, dream, dream. dreams transform into thoughts and thoughts result in action." this famous quote by dr. apj abdul kalam, india’s beloved former president and scientist, encapsulates his belief in the power of dreams to drive progress. he emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. dr. kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. his wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.\n'

# %% [markdown]
# # RegexpStemmer class
# # NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer=RegexpStemmer('ing|s$|e$|able$', min=4)

# %%
reg_stemmer.stem(corpus)
# Out:
# '"Dream, dream, dream. Dreams transform into thoughts and thoughts result in action." This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress. He emphasized that envision a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlight the importance of vision and action in achiev success. His wisdom continues to motivate generations to innovate and contribute meanfully\xa0to\xa0society.\n'

# %% [markdown]
# # Snowball Stemmer
#  It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer=SnowballStemmer("english")

# %%
for word in corpus:
    print(word+"---->"+snowballsstemmer.stem(corpus))
# Out:
# "---->"dream, dream, dream. dreams transform into thoughts and thoughts result in action." this famous quote by dr. apj abdul kalam, india's beloved former president and scientist, encapsulates his belief in the power of dreams to drive progress. he emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. dr. kalam's words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. his wisdom continues to motivate generations to innovate and contribute meaningfully to society.
#
# ...

# %%
stemming.stem(corpus)
# Out:
# '"dream, dream, dream. dreams transform into thoughts and thoughts result in action." this famous quote by dr. apj abdul kalam, india’s beloved former president and scientist, encapsulates his belief in the power of dreams to drive progress. he emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. dr. kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. his wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.\n'

# %%
snowballsstemmer.stem(corpus)
# Out:
# '"dream, dream, dream. dreams transform into thoughts and thoughts result in action." this famous quote by dr. apj abdul kalam, india\'s beloved former president and scientist, encapsulates his belief in the power of dreams to drive progress. he emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. dr. kalam\'s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. his wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.\n'

# %% [markdown]
# # Parts Of Speech Tags.

# %%
## Speech Of DR APJ Abdul Kala
corpus
# Out:
# '"Dream, dream, dream. Dreams transform into thoughts and thoughts result in action." This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress. He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes. Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success. His wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.\n'

# %%
from nltk.corpus import stopwords
sentences=nltk.sent_tokenize(corpus)

# %%
sentences
# Out:
# ['"Dream, dream, dream.',
#  'Dreams transform into thoughts and thoughts result in action."',
#  'This famous quote by Dr. APJ Abdul Kalam, India’s beloved former President and scientist, encapsulates his belief in the power of dreams to drive progress.',
#  'He emphasized that envisioning a goal sparks the thought process, which, when coupled with determination, leads to tangible outcomes.',
#  'Dr. Kalam’s words inspire students and individuals to pursue their aspirations relentlessly, highlighting the importance of vision and action in achieving success.',
#  'His wisdom continues to motivate generations to innovate and contribute meaningfully\xa0to\xa0society.']

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
import nltk
nltk.download('stopwords')
## We will find the Pos Tag

for i in range(len(sentences)):
    words=nltk.word_tokenize(sentences[i])
    words=[word for word in words if word not in set(stopwords.words('english'))]
    #sentences[i]=' '.join(words)# converting all the list of words into sentences
    pos_tag=nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ADMIN\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [('``', '``'), ('Dream', 'NN'), (',', ','), ('dream', 'NN'), (',', ','), ('dream', 'NN'), ('.', '.')]
# [('Dreams', 'NNP'), ('transform', 'NN'), ('thoughts', 'NNS'), ('thoughts', 'NNS'), ('result', 'VBP'), ('action', 'NN'), ('.', '.'), ("''", "''")]
# [('This', 'DT'), ('famous', 'JJ'), ('quote', 'NN'), ('Dr.', 'NNP'), ('APJ', 'NNP'), ('Abdul', 'NNP'), ('Kalam', 'NNP'), (',', ','), ('India', 'NNP'), ('’', 'NNP'), ('beloved', 'VBD'), ('former', 'JJ'), ('President', 'NNP'), ('scientist', 'NN'), (',', ','), ('encapsulates', 'VBZ'), ('belief', 'JJ'), ('power', 'NN'), ('dreams', 'NNS'), ('drive', 'VBP'), ('progress', 'NN'), ('.', '.')]
# ...
