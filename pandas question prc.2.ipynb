# %% [markdown]
# # AGGREGATE QUESTION PRACTICE (MAX,MIN,COUNT)

# %%
# 1. Load the `student_performance_extended.csv` dataset into a pandas DataFrame.
import pandas as pd
data=pd.read_csv(r"C:\Users\ADMIN\Documents\student_performance_extended.csv")
df=pd.DataFrame(data)

# %%
df.isnull().sum()
# Out:
# student_id      0
# name            0
# age             0
# gender          0
# subject         0
# score          11
# attendance      2
# grade           0
# study_hours     0
# dtype: int64

# %%
df.dropna(inplace=True)
df
# Out:
#    student_id           name  age gender  subject   score  attendance grade  \
# 0        S001       John Doe   18      M     Math    85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science    92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English    78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math    65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science  python        80.0     B
# ..        ...            ...  ...    ...      ...     ...         ...   ...
# 95       S096      Fred Reid   16      M  History    70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art    95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math    60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science    85.0        90.0     A
# 99       S100       Jon Holt   18      M  English    78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
df.fillna({'score': 0, 'attendance': df['attendance'].mean()}, inplace=True)
df
# Out:
#    student_id           name  age gender  subject   score  attendance grade  \
# 0        S001       John Doe   18      M     Math    85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science    92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English    78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math    65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science  python        80.0     B
# ..        ...            ...  ...    ...      ...     ...         ...   ...
# 95       S096      Fred Reid   16      M  History    70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art    95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math    60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science    85.0        90.0     A
# 99       S100       Jon Holt   18      M  English    78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#    student_id           name  age gender  subject   score  attendance grade  \
# 0        S001       John Doe   18      M     Math    85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science    92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English    78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math    65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science  python        80.0     B
# ..        ...            ...  ...    ...      ...     ...         ...   ...
# 95       S096      Fred Reid   16      M  History    70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art    95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math    60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science    85.0        90.0     A
# 99       S100       Jon Holt   18      M  English    78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
df
# Out:
#    student_id           name  age gender  subject   score  attendance grade  \
# 0        S001       John Doe   18      M     Math    85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science    92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English    78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math    65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science  python        80.0     B
# ..        ...            ...  ...    ...      ...     ...         ...   ...
# 95       S096      Fred Reid   16      M  History    70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art    95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math    60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science    85.0        90.0     A
# 99       S100       Jon Holt   18      M  English    78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
df['grade'] = df['grade'].str.title().str.strip()
df
# Out:
#    student_id           name  age gender  subject   score  attendance grade  \
# 0        S001       John Doe   18      M     Math    85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science    92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English    78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math    65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science  python        80.0     B
# ..        ...            ...  ...    ...      ...     ...         ...   ...
# 95       S096      Fred Reid   16      M  History    70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art    95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math    60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science    85.0        90.0     A
# 99       S100       Jon Holt   18      M  English    78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
#  2. Display the first 10 rows of the DataFrame.
df.head(11)
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# 5        S006      David Lee   17      M  English   88.0        92.0     A
# 6        S007     Emma Davis   19      F     Math   95.0        98.0     A
# 7        S008   Frank Miller   18      M  Science   70.0        75.0     C
# 8        S009   Grace Taylor   17      F  English   82.0        88.0     B
# 9        S010    Harry Moore   16      M     Math   60.0        65.0     D
# 10       S011       John Doe   18      M     Math   85.0        90.0     A
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
# 3. Show the column names and their data types.
df=df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   98 non-null     object
#  1   name         98 non-null     object
#  2   age          98 non-null     int64
#  3   gender       98 non-null     object
#  4   subject      98 non-null     object
#  5   score        98 non-null     object
#  6   attendance   98 non-null     float64
#  7   grade        98 non-null     object
#  8   study_hours  98 non-null     int64
# dtypes: float64(1), int64(2), object(6)
# memory usage: 7.7+ KB

# %%
#  4. Rename the `study_hours` column to `weekly_study_hours`.
df=df.rename(columns={'study_hours': 'weekly_study_hours'})
print(df)
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     weekly_study_hours
# 0                   10
# ...

# %%
# 5. Add a new column `score_percentage` by dividing `score` by 100.
df['score_percentage'] = df['score'] / 100
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     weekly_study_hours  score_percentage
# ...

# %%
#  6. Delete the `grade` column from the DataFrame.
df=df.drop(columns=['grade'])
df
# Out:
#    student_id           name  age gender  subject  score  attendance  \
# 0        S001       John Doe   18      M     Math   85.0        90.0
# 1        S002     Jane Smith   17      F  Science   92.0        95.0
# 2        S003  Alice Johnson   19      F  English   78.0        85.0
# 3        S004      Bob Brown   16      M     Math   65.0        70.0
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0
# ..        ...            ...  ...    ...      ...    ...         ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0
# 96       S097      Gail Vega   18      F      Art   95.0        98.0
# 97       S098       Hal Cole   17      M     Math   60.0        65.0
# 98       S099      Iris Beck   19      F  Science   85.0        90.0
# 99       S100       Jon Holt   18      M  English   78.0        82.0
#
#     weekly_study_hours  score_percentage
# 0                   10              0.85
# 1                   12              0.92
# ...

# %%
#  7. Use `loc` to select rows where `gender` is 'F' and `subject` is 'Science'.
p = df.loc[(df['gender'] == 'F') & (df['subject'] == 'Science')]
p
# Out:
#    student_id          name  age gender  subject  score  attendance  \
# 1        S002    Jane Smith   17      F  Science   92.0        95.0
# 4        S005  Clara Wilson   18      F  Science    NaN        80.0
# 11       S012     Ivy Clark   19      F  Science   90.0        92.0
# 17       S018  Olivia Scott   17      F  Science   88.0        90.0
# 20       S021     Rose Hall   19      F  Science   85.0        90.0
# 26       S027   Yara Brooks   17      F  Science   70.0        80.0
# 38       S039    Kylie Ross   19      F  Science   85.0        90.0
# 43       S044    Piper Lane   19      F  Science   88.0        90.0
# 51       S052     Xena Cruz   19      F  Science   70.0        80.0
# 63       S064      Joy Beck   19      F  Science   85.0        90.0
# 72       S073  Clara Wilson   18      F  Science    NaN        80.0
# 78       S079     Ivy Clark   19      F  Science   90.0        92.0
# 86       S087      Wren Fox   19      F  Science   70.0        80.0
# ...

# %%
#  8. Use `iloc` to select rows 5 to 15 and columns `student_id`, `name`, and `score`
df = df.iloc[5:16, [0, 1, 5]]
df
# Out:
#    student_id          name  score
# 5        S006     David Lee   88.0
# 6        S007    Emma Davis   95.0
# 7        S008  Frank Miller   70.0
# 8        S009  Grace Taylor   82.0
# 9        S010   Harry Moore   60.0
# 10       S011      John Doe   85.0
# 11       S012     Ivy Clark   90.0
# 12       S013    Jack White   75.0
# 13       S014    Kate Green   55.0
# 14       S015   Liam Harris   92.0
# 15       S016     Mia Adams    NaN

# %%
# 9. Count the number of null values in each column.
df.isnull().sum()
# Out:
# student_id    0
# name          0
# score         1
# dtype: int64

# %%
# 10. Fill null values in `score` with the mean score of the DataFrame.
df["score"]=df["score"].fillna(df["score"].mean())
df
# Out:
#    student_id          name  score
# 5        S006     David Lee   88.0
# 6        S007    Emma Davis   95.0
# 7        S008  Frank Miller   70.0
# 8        S009  Grace Taylor   82.0
# 9        S010   Harry Moore   60.0
# 10       S011      John Doe   85.0
# 11       S012     Ivy Clark   90.0
# 12       S013    Jack White   75.0
# 13       S014    Kate Green   55.0
# 14       S015   Liam Harris   92.0
# 15       S016     Mia Adams   79.2

# %%
# 11. Drop all duplicate rows based on all columns.
df=df.drop_duplicates()
df
# Out:
#    student_id          name  score
# 5        S006     David Lee   88.0
# 6        S007    Emma Davis   95.0
# 7        S008  Frank Miller   70.0
# 8        S009  Grace Taylor   82.0
# 9        S010   Harry Moore   60.0
# 10       S011      John Doe   85.0
# 11       S012     Ivy Clark   90.0
# 12       S013    Jack White   75.0
# 13       S014    Kate Green   55.0
# 14       S015   Liam Harris   92.0
# 15       S016     Mia Adams   79.2

# %%
# 12. Identify outliers in `score` using a simple threshold (scores below 30 or above 95).
v = df[(df['score'] < 30) | (df['score'] > 95)]
v
# Out:
#    student_id       name  age gender  subject  score  attendance grade  \
# 29       S030  Brian Fox   19      M  Science   25.0        60.0     F
# 54       S055  Adam West   19      M  Science   25.0        60.0     F
# 89       S090  Zane Ward   19      M  Science   25.0        60.0     F
#
#     study_hours
# 29            2
# 54            2
# 89            2

# %%
# 13. Calculate the average `score` for each `subject`
v = df.groupby('subject')['score'].mean()
v
# Out:
# subject
# Art        85.777778
# English    81.521739
# History    78.000000
# Math       72.185185
# Science    73.090909
# Name: score, dtype: float64

# %%
#  14. Group by `gender` and find the mean `attendance`.
v = df.groupby('gender')['attendance'].mean()
v
# Out:
# gender
# F    85.918367
# M    80.530612
# Name: attendance, dtype: float64

# %%
#  15. Find the minimum `score` for each `age`.
print(df.groupby("age")["score"].min())
# Out:
# age
# 16    60.0
# 17    60.0
# 18    45.0
# 19    25.0
# Name: score, dtype: float64

# %%
#  16. Use `loc` to set `score` to 50 for students with `attendance` below 65.
df.loc[df['attendance'] < 65, 'score'] = 50
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
# 17. Add a new column `pass_status` ('Pass' if `score` >= 60, else 'Fail').
df['pass_status'] = df['score'].apply(lambda x: 'Pass' if x >= 60 else 'Fail')
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours pass_status
# 0            10        Pass
# ...

# %%
# 18. Filter rows where `weekly_study_hours` is greater than 10.
h = df.loc[df['weekly_study_hours'] > 10]
h
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weekly_study_hours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[182], line 2
# ...

# %%
# 19. Sort the DataFrame by `age` in ascending order.
c= df.sort_values(by='age', ascending=True)
c
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 9        S010    Harry Moore   16      M     Math   60.0        65.0     D
# 14       S015    Liam Harris   16      M  Science   92.0        95.0     A
# 18       S019     Paul Young   16      M  English   80.0        88.0     B
# 27       S028      Zach Reed   16      M  English   85.0        90.0     A
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 70       S071  Alice Johnson   19      F  English   78.0        85.0     B
# 93       S094      Dean Ford   19      M  Science    NaN        80.0     B
# 89       S090      Zane Ward   19      M  Science   25.0        60.0     F
# 82       S083    Sophia Tate   19      F     Math   78.0        82.0     B
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
#
#     study_hours
# 3             5
# 9             4
# ...

# %%
#  20. Count the number of students in each `subject`.
g = df['subject'].value_counts()
g
# Out:
# subject
# Math       28
# Science    27
# English    25
# History    10
# Art        10
# Name: count, dtype: int64

# %%
#  21. Replace null values in `attendance` with 75.
df['attendance'] = df['attendance'].fillna(75)
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
# 22. Use `iloc` to select the last 10 rows and columns 0 to 4.
df.iloc[-10:, 0:5]
# Out:
#    student_id       name  age gender  subject
# 90       S091   Ava Dunn   17      F  History
# 91       S092   Ben Cook   16      M      Art
# 92       S093  Cora Lane   18      F     Math
# 93       S094  Dean Ford   19      M  Science
# 94       S095  Elle Gill   17      F  English
# 95       S096  Fred Reid   16      M  History
# 96       S097  Gail Vega   18      F      Art
# 97       S098   Hal Cole   17      M     Math
# 98       S099  Iris Beck   19      F  Science
# 99       S100   Jon Holt   18      M  English

# %%
#  23. Group by `subject` and calculate the median `score`.
print(df.groupby('subject')['Score'].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[189], line 2
#       1 #  23. Group by `subject` and calculate the median `score`.
# ----> 2 print(df.groupby('subject')['Score'].median())
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
# ...

# %%
# 24. Create a new DataFrame with `student_id`, `name`, and `subject`, then merge with the original DataFrame on `student_id` to include `attendance`.
df_original = pd.DataFrame({
    'student_id': [101, 102, 103],
    'attendance': [90, 85, 95]
})



df_new = pd.DataFrame({
    'student_id': [101, 102, 103],
    'name': ['Alice', 'Bob', 'Charlie'],
    'subject': ['Math', 'English', 'Science']
})

merged_df = pd.merge(df_new, df_original, on='student_id')
merged_df
# Out:
#    student_id     name  subject  attendance
# 0         101    Alice     Math          90
# 1         102      Bob  English          85
# 2         103  Charlie  Science          95

# %%
# 25. Concatenate the first 50 rows and the last 50 rows of the DataFrame.
a=df.head(50)
b=df.tail(50)
c = pd.concat([a, b])
c
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
# 26. Check for duplicate `student_id` values and list them.

# %%
# 27. Calculate the mean `score` for each `gender` and `subject` combination.
mean_scores = df.groupby(['gender', 'subject'])['score'].mean().reset_index()
mean_scores
# Out:
#   gender  subject      score
# 0      F      Art  95.000000
# 1      F  English  81.363636
# 2      F  History  82.800000
# 3      F     Math  76.166667
# 4      F  Science  83.166667
# 5      M      Art  81.166667
# 6      M  English  81.666667
# 7      M  History  70.000000
# 8      M     Math  69.000000
# 9      M  Science  61.000000

# %%
# 28. Use `loc` to select students with `score` above 80 and `age` below 18.
t= df.loc[(df['score'] > 80) & (df['age'] < 18)]
t
# Out:
#    student_id          name  age gender  subject  score  attendance grade  \
# 1        S002    Jane Smith   17      F  Science   92.0        95.0     A
# 5        S006     David Lee   17      M  English   88.0        92.0     A
# 8        S009  Grace Taylor   17      F  English   82.0        88.0     B
# 14       S015   Liam Harris   16      M  Science   92.0        95.0     A
# 17       S018  Olivia Scott   17      F  Science   88.0        90.0     A
# 21       S022    Sam Walker   17      M  English   90.0        92.0     A
# 27       S028     Zach Reed   16      M  English   85.0        90.0     A
# 30       S031    Chloe King   17      F  History   88.0         NaN     A
# 34       S035    Gina Hayes   17      F  English   82.0        88.0     B
# 41       S042    Nick Price   17      M      Art   90.0        92.0     A
# 46       S047     Sean Hill   17      M  Science   85.0        90.0     A
# 50       S051    Wade Burns   17      M     Math   95.0        98.0     A
# ...

# %%
#  29. Add a new column `study_efficiency` as `score` divided by `weekly_study_hours` (replace zero `weekly_study_hours` with 1 to avoid division errors).
df = pd.DataFrame({
    'student_id': [1, 2, 3],
    'score': [90, 80, 85],
    'hours_studied': [10, 8, 12]
})

adjusted_hours = df['weekly_study_hours'].replace(0, 1)

df['study_efficiency'] = df['score'] / adjusted_hours
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weekly_study_hours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[198], line 8
# ...

# %%
#  30. Group by `age` and find the maximum `score`.
max_scores_by_age = df.groupby('age')['score'].max()

print(max_scores_by_age
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[200], line 2
#       1 #  30. Group by `age` and find the maximum `score`.
# ----> 2 max_scores_by_age = df.groupby('age')['score'].max()
#       4 print(max_scores_by_age)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:9183, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9180 if level is None and by is None:
#    9181     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9183 return DataFrameGroupBy(
#    9184     obj=self,
#    9185     keys=by,
#    9186     axis=axis,
#    9187     level=level,
#    9188     as_index=as_index,
#    9189     sort=sort,
#    9190     group_keys=group_keys,
#    9191     observed=observed,
#    9192     dropna=dropna,
#    9193 )
#
# ...

# %%
#  31. Display the last 5 rows of the DataFrame.
df.tail()
# Out:
#    student_id       name  age gender  subject  score  attendance grade  \
# 95       S096  Fred Reid   16      M  History   70.0        75.0     C
# 96       S097  Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098   Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099  Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100   Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 95            6
# 96           15
# 97            4
# 98           11
# 99            7

# %%
# 32. Rename the `score` column to `exam_score`
df.rename(columns={'score': 'exam_score'}, inplace=True)
df
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 1        S002     Jane Smith   17      F  Science        92.0        95.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 3        S004      Bob Brown   16      M     Math        65.0        70.0
# 4        S005   Clara Wilson   18      F  Science         NaN        80.0
# ..        ...            ...  ...    ...      ...         ...         ...
# 95       S096      Fred Reid   16      M  History        70.0        75.0
# 96       S097      Gail Vega   18      F      Art        95.0        98.0
# 97       S098       Hal Cole   17      M     Math        60.0        65.0
# 98       S099      Iris Beck   19      F  Science        85.0        90.0
# 99       S100       Jon Holt   18      M  English        78.0        82.0
#
#    grade  study_hours
# 0      A           10
# 1      A           12
# ...

# %%
#  33. Add a new column `attendance_category` ('High' if `attendance` >= 90, else 'Low').
df['attendance_category'] = df['attendance'].apply(lambda x: 'High' if x >= 90 else 'Low')
df
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 1        S002     Jane Smith   17      F  Science        92.0        95.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 3        S004      Bob Brown   16      M     Math        65.0        70.0
# 4        S005   Clara Wilson   18      F  Science         NaN        80.0
# ..        ...            ...  ...    ...      ...         ...         ...
# 95       S096      Fred Reid   16      M  History        70.0        75.0
# 96       S097      Gail Vega   18      F      Art        95.0        98.0
# 97       S098       Hal Cole   17      M     Math        60.0        65.0
# 98       S099      Iris Beck   19      F  Science        85.0        90.0
# 99       S100       Jon Holt   18      M  English        78.0        82.0
#
#    grade  study_hours attendance_category
# ...

# %%
#  34. Use `loc` to select rows where `subject` is 'History' and `score` is above 85.
df.loc[(df['subject'] == 'History') & (df['score'] > 85)]
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 4        S005   Clara Wilson   18      F  Science    NaN        80.0     B
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
#  35. Use `iloc` to select rows 0 to 9 and columns `name`, `subject`, `exam_score`.
df=df.iloc[0:10,[1,4,5]]
df
# Out:
#             name  subject  score
# 0       John Doe     Math   85.0
# 1     Jane Smith  Science   92.0
# 2  Alice Johnson  English   78.0
# 3      Bob Brown     Math   65.0
# 4   Clara Wilson  Science    NaN
# 5      David Lee  English   88.0
# 6     Emma Davis     Math   95.0
# 7   Frank Miller  Science   70.0
# 8   Grace Taylor  English   82.0
# 9    Harry Moore     Math   60.0

# %%
#  36. Fill null values in `weekly_study_hours` with 5.
df['weekly_study_hours'].fillna(5, inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'weekly_study_hours'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
# ...

# %%
# 37. Drop rows where `score` is null.
df.dropna(subset=['score'], inplace=True)
df
# Out:
#    student_id           name  age gender  subject  score  attendance grade  \
# 0        S001       John Doe   18      M     Math   85.0        90.0     A
# 1        S002     Jane Smith   17      F  Science   92.0        95.0     A
# 2        S003  Alice Johnson   19      F  English   78.0        85.0     B
# 3        S004      Bob Brown   16      M     Math   65.0        70.0     C
# 5        S006      David Lee   17      M  English   88.0        92.0     A
# ..        ...            ...  ...    ...      ...    ...         ...   ...
# 95       S096      Fred Reid   16      M  History   70.0        75.0     C
# 96       S097      Gail Vega   18      F      Art   95.0        98.0     A
# 97       S098       Hal Cole   17      M     Math   60.0        65.0     D
# 98       S099      Iris Beck   19      F  Science   85.0        90.0     A
# 99       S100       Jon Holt   18      M  English   78.0        82.0     B
#
#     study_hours
# 0            10
# 1            12
# ...

# %%
#  38. Identify outliers in `attendance` using a threshold (attendance below 60).
c=df[df["attendance"]<60]
c
# Out:
# Empty DataFrame
# Columns: [student_id, name, age, gender, subject, score, attendance, grade, study_hours]
# Index: []

# %%
#  39. Calculate the sum of `weekly_study_hours` for each `subject`.

# %%
#  40. Group by `gender` and `age`, then find the average `exam_score`
df.groupby(['gender', 'age'])['exam_score'].mean().reset_index()
df
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 1        S002     Jane Smith   17      F  Science        92.0        95.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 3        S004      Bob Brown   16      M     Math        65.0        70.0
# 4        S005   Clara Wilson   18      F  Science         NaN        80.0
# ..        ...            ...  ...    ...      ...         ...         ...
# 95       S096      Fred Reid   16      M  History        70.0        75.0
# 96       S097      Gail Vega   18      F      Art        95.0        98.0
# 97       S098       Hal Cole   17      M     Math        60.0        65.0
# 98       S099      Iris Beck   19      F  Science        85.0        90.0
# 99       S100       Jon Holt   18      M  English        78.0        82.0
#
#    grade  study_hours
# 0      A           10
# 1      A           12
# ...

# %%
#  41. Use `loc` to update `exam_score` to 60 for students with `exam_score` below 60.
df.loc[df['exam_score'] < 60, 'exam_score'] = 60
df
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 1        S002     Jane Smith   17      F  Science        92.0        95.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 3        S004      Bob Brown   16      M     Math        65.0        70.0
# 4        S005   Clara Wilson   18      F  Science         NaN        80.0
# ..        ...            ...  ...    ...      ...         ...         ...
# 95       S096      Fred Reid   16      M  History        70.0        75.0
# 96       S097      Gail Vega   18      F      Art        95.0        98.0
# 97       S098       Hal Cole   17      M     Math        60.0        65.0
# 98       S099      Iris Beck   19      F  Science        85.0        90.0
# 99       S100       Jon Holt   18      M  English        78.0        82.0
#
#    grade  study_hours
# 0      A           10
# 1      A           12
# ...

# %%
#  42. Filter rows where `exam_score` is between 70 and 90.
c= df[(df['exam_score'] >= 70) & (df['exam_score'] <= 90)]
c
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 5        S006      David Lee   17      M  English        88.0        92.0
# 7        S008   Frank Miller   18      M  Science        70.0        75.0
# 8        S009   Grace Taylor   17      F  English        82.0        88.0
# 10       S011       John Doe   18      M     Math        85.0        90.0
# 11       S012      Ivy Clark   19      F  Science        90.0        92.0
# 12       S013     Jack White   17      M  English        75.0        85.0
# 17       S018   Olivia Scott   17      F  Science        88.0        90.0
# 18       S019     Paul Young   16      M  English        80.0        88.0
# 19       S020   Quinn Turner   18      F     Math        78.0        82.0
# 20       S021      Rose Hall   19      F  Science        85.0        90.0
# ...

# %%
#  43. Sort the DataFrame by `weekly_study_hours` in descending order.

# %%
#  44. Count the number of students with `pass_status` as 'Pass'.
pass_count = (df['pass_status'] == 'Pass').sum()
pass_count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pass_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 2
# ...

# %%
#  45. Replace null values in `exam_score` with the median score of the respective `subject`.
df['exam_score'] = df['exam_score'].fillna(
    df.groupby('subject')['exam_score'].transform('median')
)
df
# Out:
#    student_id           name  age gender  subject  exam_score  attendance  \
# 0        S001       John Doe   18      M     Math        85.0        90.0
# 1        S002     Jane Smith   17      F  Science        92.0        95.0
# 2        S003  Alice Johnson   19      F  English        78.0        85.0
# 3        S004      Bob Brown   16      M     Math        65.0        70.0
# 4        S005   Clara Wilson   18      F  Science        85.0        80.0
# ..        ...            ...  ...    ...      ...         ...         ...
# 95       S096      Fred Reid   16      M  History        70.0        75.0
# 96       S097      Gail Vega   18      F      Art        95.0        98.0
# 97       S098       Hal Cole   17      M     Math        60.0        65.0
# 98       S099      Iris Beck   19      F  Science        85.0        90.0
# 99       S100       Jon Holt   18      M  English        78.0        82.0
#
#    grade  study_hours attendance_category
# ...

# %%
#  46. Use `iloc` to select every third row from the first 30 rows and columns `student_id`, `name`.
df.iloc[range(0, 30, 3)][['student_id', 'name']]
# Out:
#    student_id         name
# 0        S001     John Doe
# 3        S004    Bob Brown
# 6        S007   Emma Davis
# 9        S010  Harry Moore
# 12       S013   Jack White
# 15       S016    Mia Adams
# 18       S019   Paul Young
# 21       S022   Sam Walker
# 24       S025  Wendy Lopez
# 27       S028    Zach Reed

# %%
#  47. Group by `subject` and find the minimum and maximum `attendance`.
df.groupby('subject')['attendance'].agg(['min', 'max'])
# Out:
#           min   max
# subject
# Art      85.0  98.0
# English  75.0  92.0
# History  70.0  95.0
# Math     60.0  98.0
# Science  60.0  95.0

# %%
# 48. Create a new DataFrame with `student_id`, `exam_score`, and `subject`, then merge with the original DataFrame on `student_id` to include `weekly_study_hours`.
df_subset = df[['student_id', 'exam_score', 'subject']]
merged_df = df_subset.merge(df[['student_id', 'weekly_study_hours']], on='student_id', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 3
#       1 # 48. Create a new DataFrame with `student_id`, `exam_score`, and `subject`, then merge with the original DataFrame on `student_id` to include `weekly_study_hours`.
#       2 df_subset = df[['student_id', 'exam_score', 'subject']]
# ----> 3 merged_df = df_subset.merge(df[['student_id', 'weekly_study_hours']], on='student_id', how='left')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
#  49. Concatenate rows where `subject` is 'Math' with rows where `subject` is 'English'.
math_df = df[df['subject'] == 'Math']
english_df = df[df['subject'] == 'English']
combined_rows = pd.concat([math_rows, english_rows], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 4
#       2 math_df = df[df['subject'] == 'Math']
#       3 english_df = df[df['subject'] == 'English']
# ----> 4 combined_rows = pd.concat([math_rows, english_rows], ignore_index=True)
#
# NameError: name 'math_rows' is not defined

# %%
# 50. Calculate the standard deviation of `exam_score` for each `age` group.
print(df.groupby("exam_score")["age"].std())
# Out:
# exam_score
# 25.0    0.000000
# 45.0    0.000000
# 55.0         NaN
# 60.0    0.834523
# 65.0    0.000000
# 70.0    1.302470
# 75.0    0.547723
# 78.0    0.517549
# 80.0    0.000000
# 82.0    0.755929
# 85.0    1.272078
# 88.0    0.925820
# 90.0    0.834523
# 92.0    0.707107
# 95.0    0.755929
# Name: age, dtype: float64
