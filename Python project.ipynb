# %%
# Guess the Number

# %%
import  random

# %%
target = random.randint(1, 100)

# %%
 while True:
    userchoice = int(input("guess the target : "))
    if(userchoice == target):
        print("Success : correct guess!!")
        break
    elif(userchoice < target):
        print("your number was too small. take a bigger guess")
    else:
        print("your numbe was too big. take a smaller guess")

print(" --game over-- ")
# Out:
# guess the target :  20
# your number was too small. take a bigger guess
# guess the target :  40
# your number was too small. take a bigger guess
# guess the target :  50
# your number was too small. take a bigger guess
# guess the target :  80
# your numbe was too big. take a smaller guess
# guess the target :  62
# Success : correct guess!!
#  --game over--

# %%
# Random Password Generator

# %%
import random
import string

# %%
print(string.ascii_letters)
# Out:
# abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ

# %%
val = random.choice([10,20,30,70])
print(val)
# Out:
# 70

# %%
print(random.choice("hello"))
# Out:
# e

# %%
charvalues = string.ascii_letters + string.digits + string.punctuation

pass_len = 8
password = ""
for i in range(pass_len):
    password += random.choice(charvalues)

print("your random password is:", password)
# Out:
# your random password is: I@$)XllR
