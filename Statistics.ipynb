# %% [markdown]
# # Measures of central tendency

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ar = np.array([1,2,3,4,10])
ar
# Out:
# array([ 1,  2,  3,  4, 10])

# %%
np.sum(ar)/len(ar)
# Out:
# np.float64(4.0)

# %%
len(ar)
# Out:
# 5

# %%
np.sort(ar)
# Out:
# array([ 1,  2,  3,  4, 10])

# %%
np.mean(ar)
# Out:
# np.float64(4.0)

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Documents\student_scores.csv")
dataset.head()
# Out:
#    StudyHours  Attendance  AssignmentsCompleted  ExamScore
# 0           5          80                     8         65
# 1           7          85                    10         72
# 2           3          70                     5         55
# 3           9          90                    12         80
# 4           6          75                     7         68

# %%
dataset.isnull().sum()
# Out:
# StudyHours              0
# Attendance              0
# AssignmentsCompleted    0
# ExamScore               0
# dtype: int64

# %%
dataset["ExamScore"].mean()
# Out:
# np.float64(72.08)

# %% [markdown]
# #  OR

# %%
mn = np.mean(dataset["ExamScore"])

# %%
dataset["Attendance"].median()
# Out:
# 83.5

# %%
md=np.median(dataset["Attendance"])

# %% [markdown]
# # or

# %%
dataset["Attendance"].median()
# Out:
# 83.5

# %%
sns.histplot(x="Attendance", data=dataset,bins=[i for i in range(0,15,2)])
plt.plot([mn for i in range(0,20)],[i for i in range(0,20)],c="red")
plt.plot([md for i in range(0,20)],[i for i in range(0,20)],c="blue")
plt.show()

# %%
sns.histplot(x="StudyHours", data=dataset,bins=[i for i in range(0,15,2)])
plt.plot([mn for i in range(0,20)],[i for i in range(0,20)],c="red")
plt.show()

# %%
 dataset["Attendance"].mode()
# Out:
# 0    80
# Name: Attendance, dtype: int64

# %%
 dataset["Attendance"].value_counts()
# Out:
# Attendance
# 80    3
# 85    2
# 70    2
# 90    2
# 88    2
# 95    2
# 87    2
# 94    2
# 96    2
# 92    2
# 97    2
# 75    1
# 65    1
# 82    1
# 72    1
# 98    1
# 84    1
# 68    1
# 99    1
# 76    1
# 78    1
# 60    1
# 91    1
# 89    1
# 62    1
# 83    1
# 74    1
# 93    1
# 67    1
# 86    1
# 79    1
# 81    1
# 66    1
# 73    1
# 77    1
# 69    1
# 64    1
# 61    1
# Name: count, dtype: int64

# %% [markdown]
# # Measures of variability

# %% [markdown]
# # RANGE = max - min

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
  dataset = pd.read_csv(r"C:\Users\ADMIN\Documents\house_prices.csv")

# %%
dataset.head()
# Out:
#    Size  Bedrooms  Age   Price
# 0  1500         3   10  250000
# 1  1800         4    5  320000
# 2  1200         2   20  180000
# 3  2000         4    8  350000
# 4  1600         3   15  260000

# %%
min_r = dataset["Bedrooms"].min()
max_r = dataset["Bedrooms"].max()

# %%
min_r,max_r
# Out:
# (2, 6)

# %%
range  = max_r - min_r
range
# Out:
# 4

# %% [markdown]
# # Mean Absolute Deviation - gives idea about variability.

# %%
ab = np.array([25,60,45,20,14])
cd = np.array([18,45,14,54,65]) 
no = np.array([1,2,3,4,5])

# %%
mean = np.mean(cd)
mean
# Out:
# np.float64(39.2)

# %%
ab = np.sum(np.abs(ab-mean))/len(ab)
cd = np.sum(np.abs(cd-mean))/len(cd)

# %%
ab
cd
# Out:
# np.float64(18.56)

# %%
ab = [65, 70, 75, 80, 85]
cd = [60, 68, 72, 78, 90]
no = [1, 2, 3, 4, 5]

# %%
plt.figure(figsize=(7,2))
plt.scatter(ab, no, label="ab")
plt.scatter(cd, no, color="red", label="cd")
plt.plot([70]*len(no), no, c="yellow", label="mean")
plt.legend()
plt.show()

# %%
np.std(ab) , np.std(cd)
# Out:
# (np.float64(7.0710678118654755), np.float64(10.071742649611338))

# %%
np.var(ab) , np.var(cd)
# Out:
# (np.float64(50.0), np.float64(101.44))

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset  = pd.read_csv(r"C:\Users\ADMIN\Documents\house_prices.csv")
dataset.head()
# Out:
#    Size  Bedrooms  Age   Price
# 0  1500         3   10  250000
# 1  1800         4    5  320000
# 2  1200         2   20  180000
# 3  2000         4    8  350000
# 4  1600         3   15  260000

# %%
dataset["Age"].var()
# Out:
# 49.25551020408163

# %%
dataset["Age"].std()
# Out:
# 7.01822699861451

# %%
dataset.describe()
# Out:
#               Size   Bedrooms        Age          Price
# count    50.000000  50.000000  50.000000      50.000000
# mean   1793.000000   3.560000   9.640000  307100.000000
# std     420.520814   1.145711   7.018227   96463.432852
# min    1100.000000   2.000000   0.000000  150000.000000
# 25%    1450.000000   3.000000   4.250000  226250.000000
# 50%    1775.000000   4.000000   7.500000  312500.000000
# 75%    2100.000000   4.000000  14.750000  363750.000000
# max    2600.000000   6.000000  25.000000  500000.000000

# %%
plt.figure(figsize=(7,3))
sns.histplot(x="Age",data=dataset)
plt.show()

# %% [markdown]
# #  Percentage and Percentiles & Quartiles.

# %% [markdown]
# # Percentage - individual value
# # Percentiles -  Ranking System  - Superior - values are lower than.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Documents\house_prices.csv")
dataset.head()
# Out:
#    Size  Bedrooms  Age   Price
# 0  1500         3   10  250000
# 1  1800         4    5  320000
# 2  1200         2   20  180000
# 3  2000         4    8  350000
# 4  1600         3   15  260000

# %%
dataset.isnull().sum()
# Out:
# Size        0
# Bedrooms    0
# Age         0
# Price       0
# dtype: int64

# %%
dataset["Age"].head()
# Out:
# 0    10
# 1     5
# 2    20
# 3     8
# 4    15
# Name: Age, dtype: int64

# %%
np.percentile(dataset["Age"],25)
# Out:
# np.float64(4.25)

# %%
dataset.describe()
# Out:
#               Size   Bedrooms        Age          Price
# count    50.000000  50.000000  50.000000      50.000000
# mean   1793.000000   3.560000   9.640000  307100.000000
# std     420.520814   1.145711   7.018227   96463.432852
# min    1100.000000   2.000000   0.000000  150000.000000
# 25%    1450.000000   3.000000   4.250000  226250.000000
# 50%    1775.000000   4.000000   7.500000  312500.000000
# 75%    2100.000000   4.000000  14.750000  363750.000000
# max    2600.000000   6.000000  25.000000  500000.000000

# %%
sns.boxplot(x="Age",data=dataset)
plt.show()

# %% [markdown]
#  # MEASURES OF SHAPE

# %% [markdown]
# # Skewness - measures the symmetry of the distribution.
# # negative skewed - left side tail
# # normal skewed - no skew .
# # positively skewed - right side tail.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Documents\house_prices.csv")
dataset.head()
# Out:
#    Size  Bedrooms  Age   Price
# 0  1500         3   10  250000
# 1  1800         4    5  320000
# 2  1200         2   20  180000
# 3  2000         4    8  350000
# 4  1600         3   15  260000

# %%
dataset["Age"].skew()
# Out:
# np.float64(0.6688934807679177)

# %%
sns.histplot(x="Age",data=dataset)
plt.show()

# %%
data = np.random.normal(0,50,50)
data
# Out:
# array([  50.40315476,   -0.6773787 ,   49.08300057,    7.94640201,
#         -36.11524652,  -14.07110612,    8.2906199 ,   -3.77424827,
#          18.84095285,  -10.52464692,  -60.80136419,  -27.95413781,
#         -39.0867665 ,  -11.39120875,   18.19921943,  -86.01373732,
#         -17.82083576,    8.95001783,  -32.28610836,   -2.45020975,
#         -54.07403993, -114.8448807 ,   22.10082701,  -54.74455982,
#         -28.02616111,  -49.84012126,  -45.90034354,   62.48009911,
#           8.83008098,   11.85534273,  -41.98022984,   51.57818074,
#           7.11059018,   47.83970984,   59.32684585,   30.39368348,
#          23.13809402,  -21.03441263,  -37.54326943,    1.11848323,
#         -12.30010464,  -29.11582487,  -16.81139483,   24.83648915,
#        -146.72250863,   -3.62689342,   30.58966595,   30.881984  ,
#        -125.28549239,    8.63909225])

# %%
df=pd.DataFrame({"x":data}).head()
df["x"].skew()
# Out:
# np.float64(-0.34254880512583064)

# %%
sns.histplot(x="x",data=df)
plt.show()

# %% [markdown]
# # PROBABILITY - chance of occuring an particular outcome.

# %% [markdown]
# # DISCRETE - deals with countable item .
# # CONTINUOUS - deals with uncountable item in a range.

# %% [markdown]
# # Probibility distribution function -
# # 1- PDF - prab. density function. - gives range. - use when data is continuous  nature
# # 2- PMF - prob. mass function. - use when data is in discrete in nature.
# # 3- CDF - cummulative Density function.

# %% [markdown]
# # COVARIANCE AND CORRELATION.
#
# # Covariance - to find relationship between two variables.
#
# # Correlation - refers to relationship between two numerically measured continuous variables.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Documents\house_prices.csv")
dataset.head()
# Out:
#    Size  Bedrooms  Age   Price
# 0  1500         3   10  250000
# 1  1800         4    5  320000
# 2  1200         2   20  180000
# 3  2000         4    8  350000
# 4  1600         3   15  260000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Size      50 non-null     int64
#  1   Bedrooms  50 non-null     int64
#  2   Age       50 non-null     int64
#  3   Price     50 non-null     int64
# dtypes: int64(4)
# memory usage: 1.7 KB

# %%
dataset.isnull().sum()
# Out:
# Size        0
# Bedrooms    0
# Age         0
# Price       0
# dtype: int64

# %%
data_corr = dataset.select_dtypes(["int64"]).corr()

# %%
dataset.select_dtypes(["int64"]).cov()
# Out:
#                   Size       Bedrooms            Age         Price
# Size      1.768378e+05     465.224490   -2749.510204  4.037214e+07
# Bedrooms  4.652245e+02       1.312653      -7.447347  1.075755e+05
# Age      -2.749510e+03      -7.447347      49.255510 -6.382082e+05
# Price     4.037214e+07  107575.510204 -638208.163265  9.305194e+09

# %%
sns.heatmap(data_corr,annot=True)
plt.show()

# %% [markdown]
# #  Central Limit Theorem - applies on large population data to find out mean by taking few samples from data.

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pop_data = [np.random.randint(10,100) for i in range(10000)]
pop_table = pd.DataFrame({"Pop_data":pop_data})

# %%
np.mean(pop_data)
# Out:
# np.float64(54.6927)

# %%
plt.figure(figsize=(4,2))
sns.kdeplot(x="Pop_data",data=pop_table)
plt.show()

# %%
sample_mean = []
for no_sample in range(60):
    sample_data = [] 
    for data in range(500):
        sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
np.mean(sample_mean)
# Out:
# np.float64(54.55596666666666)

# %%
sample_M = pd.DataFrame({"Sample_Mean":sample_mean})

# %%
sns.kdeplot(x="Sample_Mean", data=sample_M)
plt.show()

# %% [markdown]
# # HYPOTHESIS TESTING - it is used when we were to compare a single group with an two or more groups with each other.

# %% [markdown]
# # Z-TEST - work on  average - work on sample data.
# # T-TEST
# # CHI-SQUARE-TEST - goodness. - check relation between two data.
