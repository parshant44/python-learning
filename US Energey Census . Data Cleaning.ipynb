# %%
import pandas as pd

# %%
dataset = pd.read_csv(r"C:\Users\ADMIN\Downloads\archive\Energy Census and Economic Data US 2010-2014.csv")
dataset.head()
# Out:
#   StateCodes       State  Region  Division  Coast  Great Lakes  TotalC2010  \
# 0         AL     Alabama     3.0       6.0    1.0          0.0     1931522
# 1         AK      Alaska     4.0       9.0    1.0          0.0      653221
# 2         AZ     Arizona     4.0       8.0    0.0          0.0     1383531
# 3         AR    Arkansas     3.0       7.0    0.0          0.0     1120632
# 4         CA  California     4.0       9.0    1.0          0.0     7760629
#
#    TotalC2011  TotalC2012  TotalC2013  ...  RINTERNATIONALMIG2013  \
# 0     1905207     1879716     1919365  ...               1.165832
# 1      653637      649341      621107  ...               3.203618
# 2     1424944     1395839     1414383  ...               1.090035
# 3     1122544     1067642     1096438  ...               2.141877
# 4     7777115     7564063     7665241  ...               4.207353
#
#    RINTERNATIONALMIG2014  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# ...

# %%
dataset.isnull().sum()
# Out:
# StateCodes          0
# State               0
# Region              0
# Division            0
# Coast               0
#                    ..
# RDOMESTICMIG2014    0
# RNETMIG2011         0
# RNETMIG2012         0
# RNETMIG2013         0
# RNETMIG2014         0
# Length: 192, dtype: int64

# %%
dataset.shape
# Out:
# (52, 192)

# %%
dataset.drop_duplicates (inplace=True)
dataset
# Out:
#    StateCodes                 State  Region  Division  Coast  Great Lakes  \
# 0          AL               Alabama     3.0       6.0    1.0          0.0
# 1          AK                Alaska     4.0       9.0    1.0          0.0
# 2          AZ               Arizona     4.0       8.0    0.0          0.0
# 3          AR              Arkansas     3.0       7.0    0.0          0.0
# 4          CA            California     4.0       9.0    1.0          0.0
# 5          CO              Colorado     4.0       8.0    0.0          0.0
# 6          CT           Connecticut     1.0       1.0    1.0          0.0
# 7          DE              Delaware     3.0       5.0    1.0          0.0
# 8          FL               Florida     3.0       5.0    1.0          0.0
# 9          GA               Georgia     3.0       5.0    1.0          0.0
# 10         HI                Hawaii     4.0       9.0    1.0          0.0
# 11         ID                 Idaho     4.0       8.0    0.0          0.0
# ...

# %%
dataset.fillna({"Region": dataset["Region"].mode()[0]}, inplace=True)
dataset
# Out:
#    StateCodes                 State  Region  Division  Coast  Great Lakes  \
# 0          AL               Alabama     3.0       6.0    1.0          0.0
# 1          AK                Alaska     4.0       9.0    1.0          0.0
# 2          AZ               Arizona     4.0       8.0    0.0          0.0
# 3          AR              Arkansas     3.0       7.0    0.0          0.0
# 4          CA            California     4.0       9.0    1.0          0.0
# 5          CO              Colorado     4.0       8.0    0.0          0.0
# 6          CT           Connecticut     1.0       1.0    1.0          0.0
# 7          DE              Delaware     3.0       5.0    1.0          0.0
# 8          FL               Florida     3.0       5.0    1.0          0.0
# 9          GA               Georgia     3.0       5.0    1.0          0.0
# 10         HI                Hawaii     4.0       9.0    1.0          0.0
# 11         ID                 Idaho     4.0       8.0    0.0          0.0
# ...

# %%
dataset.fillna({"Division": dataset["Division"].mode()[0]}, inplace=True)
dataset
# Out:
#    StateCodes                 State  Region  Division  Coast  Great Lakes  \
# 0          AL               Alabama     3.0       6.0    1.0          0.0
# 1          AK                Alaska     4.0       9.0    1.0          0.0
# 2          AZ               Arizona     4.0       8.0    0.0          0.0
# 3          AR              Arkansas     3.0       7.0    0.0          0.0
# 4          CA            California     4.0       9.0    1.0          0.0
# 5          CO              Colorado     4.0       8.0    0.0          0.0
# 6          CT           Connecticut     1.0       1.0    1.0          0.0
# 7          DE              Delaware     3.0       5.0    1.0          0.0
# 8          FL               Florida     3.0       5.0    1.0          0.0
# 9          GA               Georgia     3.0       5.0    1.0          0.0
# 10         HI                Hawaii     4.0       9.0    1.0          0.0
# 11         ID                 Idaho     4.0       8.0    0.0          0.0
# ...

# %%
dataset.fillna({"Coast": dataset["Coast"].mode()[0]}, inplace=True)
dataset
# Out:
#    StateCodes                 State  Region  Division  Coast  Great Lakes  \
# 0          AL               Alabama     3.0       6.0    1.0          0.0
# 1          AK                Alaska     4.0       9.0    1.0          0.0
# 2          AZ               Arizona     4.0       8.0    0.0          0.0
# 3          AR              Arkansas     3.0       7.0    0.0          0.0
# 4          CA            California     4.0       9.0    1.0          0.0
# 5          CO              Colorado     4.0       8.0    0.0          0.0
# 6          CT           Connecticut     1.0       1.0    1.0          0.0
# 7          DE              Delaware     3.0       5.0    1.0          0.0
# 8          FL               Florida     3.0       5.0    1.0          0.0
# 9          GA               Georgia     3.0       5.0    1.0          0.0
# 10         HI                Hawaii     4.0       9.0    1.0          0.0
# 11         ID                 Idaho     4.0       8.0    0.0          0.0
# ...

# %%
dataset.fillna({"RDOMESTICMIG2014": dataset["RDOMESTICMIG2014"].mode()[0]}, inplace=True)
dataset
# Out:
#    StateCodes                 State  Region  Division  Coast  Great Lakes  \
# 0          AL               Alabama     3.0       6.0    1.0          0.0
# 1          AK                Alaska     4.0       9.0    1.0          0.0
# 2          AZ               Arizona     4.0       8.0    0.0          0.0
# 3          AR              Arkansas     3.0       7.0    0.0          0.0
# 4          CA            California     4.0       9.0    1.0          0.0
# 5          CO              Colorado     4.0       8.0    0.0          0.0
# 6          CT           Connecticut     1.0       1.0    1.0          0.0
# 7          DE              Delaware     3.0       5.0    1.0          0.0
# 8          FL               Florida     3.0       5.0    1.0          0.0
# 9          GA               Georgia     3.0       5.0    1.0          0.0
# 10         HI                Hawaii     4.0       9.0    1.0          0.0
# 11         ID                 Idaho     4.0       8.0    0.0          0.0
# ...

# %%
X = dataset.drop(columns=["Coast","Great Lakes",])  # Drop irrelevant columns
y = dataset['death']  # ✅ This is a 1D Series
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'death'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
# ...
